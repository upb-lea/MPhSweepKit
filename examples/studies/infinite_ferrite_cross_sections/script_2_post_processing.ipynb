# %%
# %load_ext autoreload
# %autoreload 2

# %%
import mph
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patheffects as pe

import mphsweepkit as msk

# %%
# Start the COMSOL client
client = mph.start()

# %%
# Load the model
model = client.load('core_cross_section_solved.mph')

# %% [markdown]
# Load an already solved CascadedSweepModel

# %%
csm = msk.CascadedSweepModel(model, 'Study on Cross-Sections')
# Out:
# Initialized CascadedSweepModel
# Study name: Study on Cross-Sections
# Sweep Structure:
#     - Geometry Sweep (BatchSweep)
#       - Material Sweep (MaterialSweep)
#         - Excitation Sweep (Parametric)
#           - Frequency Sweep (Frequency)
# --------------------------------
# Data updated from MPh-model.
# Input data shape: (156, 8)
# Reset output data to shape of the input data: (156, 0)
# Combined shape: (156, 8)

# %% [markdown]
# Post-processing

# %%
csm.model_datasets
# Out:
# ['Study on Cross-Sections//Solution 1',
#  'Study on Cross-Sections//Parametric Solutions 1']

# %%
# Load the customized post-processing expressions from a JSON file
post_processing_exprs = msk.load_post_processing_exprs("post_processing_expressions.json")
# Out:
# post_processing_expressions.json

# %%
csm.post_process(post_processing_exprs)

# %%
csm.combined_data
# Out:
#      hor_slit  vert_slit     w  l_r   a_e  matsw.comp1.core  b_mean    freq  \
# 0         0.0        0.0   5.0  0.0   5.0               2.0    25.0   100.0
# 1         0.0        0.0   5.0  0.0   5.0               2.0    25.0   200.0
# 2         0.0        0.0   5.0  0.0   5.0               2.0    25.0   300.0
# 3         0.0        0.0   5.0  0.0   5.0               2.0    25.0   400.0
# 4         0.0        0.0   5.0  0.0   5.0               2.0    25.0   500.0
# ..        ...        ...   ...  ...   ...               ...     ...     ...
# 151       0.0        0.0  15.0  0.0  15.0               2.0   100.0   900.0
# 152       0.0        0.0  15.0  0.0  15.0               2.0   100.0  1000.0
# 153       0.0        0.0  15.0  0.0  15.0               2.0   100.0  1100.0
# 154       0.0        0.0  15.0  0.0  15.0               2.0   100.0  1200.0
# 155       0.0        0.0  15.0  0.0  15.0               2.0   100.0  1300.0
#
#            p_loss         p_mag          p_el
# 0    1.065209e+03  1.016231e+03  4.897800e+01
# 1    2.817933e+03  2.542728e+03  2.752049e+02
# 2    5.421143e+03  4.629192e+03  7.919502e+02
# 3    9.291744e+03  7.584089e+03  1.707656e+03
# 4    1.497961e+04  1.185114e+04  3.128464e+03
# ..            ...           ...           ...
# 151  6.288120e+06  3.096518e+06  3.191601e+06
# 152  9.016708e+06  4.543201e+06  4.473508e+06
# 153  1.238691e+07  6.479828e+06  5.907080e+06
# 154  1.620001e+07  8.875677e+06  7.324329e+06
# 155  2.024209e+07  1.167374e+07  8.568350e+06
#
# [156 rows x 11 columns]

# %% [markdown]
# Save post-processing results

# %%
csm.save_result_data()
# Out:
# Saved result data to: X:\Till_data\repositories\MPhSweepKit\examples\studies\infinite_ferrite_cross_sections\result_data

# %% [markdown]
# Release Model

# %%
client.remove(model)
client.clear()
client.disconnect()
